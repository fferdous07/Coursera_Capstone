# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>
#
# I want to start a new highend indian fusion restaurant. I am open to toronto and NY area. I want to select a location based on following
#
# 1. Mean and min income of a neighborhood
# 2. Age group
# 3. Presense of other indian restaurants in the neighborhood
# 3. Is the neighborhood mulicultured or not
#
# People wants to try new food in a highend environment will be very interested to my restaurant. Also investors and people who like different culture and very interested to try diferent food and at the same time earn a good income will care my business analysis.

# %% [markdown]
# ## Data and Solution idea:
#
# In previous projects, we got the data from Toronto and NY. Also How to use Foursquare app and machine learning.
#
#
# 1. I will use both Toronto and NY data to get the selection information. Candidate locations will be generated algorithmically (Mean and min income of a neighborhood;
# Age group and mulicultured or not) and approximate addresses of centers of those areas will be obtained using Google Maps API reverse geocoding
# 2. Once I selected a venue. Number of Indian restaurants and their ranking and tips and location in every neighborhood will be obtained using Foursquare API
# 3. coordinate of final selection will be obtained using Google Maps API geocoding. I will try to predict how many people will visit a new restaurant. For that I will segment the data into train and test data and apply Mulitple linear regression. I will select a place where prdiction is high.
