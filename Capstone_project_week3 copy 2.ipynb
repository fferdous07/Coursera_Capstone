# %% [markdown]
# In this assignment, Toronto neighborhood data is prepared from a Wikipedia page.
#
# Data preparation requirement:
#
# 1. Scrape the Wikipedia page and wrangle the data
# 2. Clean it
# 3. Read it into a pandas  dataframe so that it is in a structured format like the New York dataset.

# %%
# importing library

import pandas as pd 

import requests 

from bs4 import BeautifulSoup

# %% [markdown]
# Following codes are to Scrape the Wikipedia page, wrangle the data and save as data frame using beautifulsoup and Pandas

# %%
# importing data from wiki

file_url="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
req = requests.get(file_url) 

# Using beautifulsoup

soup = BeautifulSoup(req.content,'lxml') 

# looking dor tables

table = soup.find_all('table')[0]  

df = pd.read_html(str(table))

# %%
# converting to dataframes, printing the size 

nb=pd.DataFrame(df[0]) 


snb=nb.shape
col_nb=snb[1]
row_nb=snb[0]

print('Row: ',row_nb,)
print('Column: ',col_nb)
# Out:
# Row:  20
# Column:  9

# %% [markdown]
# Following code in the test code to required information. It is part of data cleaning

# %%
# Initial code for algorithom check for data cleaning

a=nb[4][0]
print(a)
pc=a[0:3]
ll=len(a)
lf=a.find('(', 2, ll)
br=a[3:lf]
if(br!='Not assigne'):
    nr=a[lf+1:ll-1]
    if(lf>-1):
        nr=nr.replace(' / ', ', ')

if(br=='Not assigne'):
    br='Not assigned'
    nr='Not assigned'
    
    
print('Postal code: ',pc)
print('Borough: ', br)
print('Neighborhood: ',nr)
# Out:
# M5ADowntown Toronto(Regent Park / Harbourfront)
# Postal code:  M5A
# Borough:  Downtown Toronto
# Neighborhood:  Regent Park, Harbourfront

# %% [markdown]
# Followings are columns name

# %%
head=['Postal_code','Borough','Neighborhood']
my_dict = {'Postal_code','Borough','Neighborhood'}

# %% [markdown]
# Following is the main portion of data cleaning

# %%
data_toronto1=['Intial','Intial','Intial']
for i, j in nb.iteritems():
    aa=nb[i]
    for t in range(20):
        a=aa[t]
        #print(a)
        pc=a[0:3]
        ll=len(a)
        lf=a.find('(', 2, ll)
        #print(lf)
        br=a[3:lf]
        
        if(br!='Not assigne'):
            nr=a[lf+1:ll-1]
            if(lf>-1):
                nr=nr.replace(' / ', ', ')
                if(br=='Not assigne'):
                    br='Not assigned'
                    nr='Not assigned'
           
            data_toronto1 = data_toronto1 + [pc, 
                                             br, 
                                             nr]
        
            #print(pc)
            #df.append({'Postal_code': pc},{'Borough': br},{'Neighborhood': nr})

# %% [markdown]
# Cleaning data continue

# %%
i=0
while(i<3):
    data_toronto1.pop(0)
    i=i+1
    print(i)
# Out:
# 1
# 2
# 3

# %%
len(data_toronto1)

# %% [markdown]
# Initializing datframes for step3:

# %%
data1=[data_toronto1[0], data_toronto1[1],data_toronto1[2]]

db_f=pd.DataFrame(data1).transpose()
db_f.columns = ['Postal_code','Borough','Neighborhood']

# %%
db_f.head()
# Out:
#   Postal_code      Borough    Neighborhood
# 0         M1B  Scarborough  Malvern, Rouge

# %% [markdown]
# Main code dataframes for step3 (ignore index error):

# %%
i=3

for k in range(len(data_toronto1)-3):
  
    db_f.loc[len(db_f.index)] = [data_toronto1[i], data_toronto1[i+1],data_toronto1[i+2]] 
    
    i=i+3
    #print(i)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-6b6bd3472420> in <module>
#       3 for k in range(len(data_toronto1)-3):
#       4
# ----> 5     db_f.loc[len(db_f.index)] = [data_toronto1[i], data_toronto1[i+1],data_toronto1[i+2]]
#       6
#       7     i=i+3
#
# IndexError: list index out of range

# %% [markdown]
# Print first 10 rows

# %%
db_f.head(10)
# Out:
#   Postal_code      Borough                                     Neighborhood
# 0         M1B  Scarborough                                   Malvern, Rouge
# 1         M1C  Scarborough           Rouge Hill, Port Union, Highland Creek
# 2         M1E  Scarborough                Guildwood, Morningside, West Hill
# 3         M1G  Scarborough                                           Woburn
# 4         M1H  Scarborough                                        Cedarbrae
# 5         M1J  Scarborough                              Scarborough Village
# 6         M1K  Scarborough      Kennedy Park, Ionview, East Birchmount Park
# 7         M1L  Scarborough                  Golden Mile, Clairlea, Oakridge
# 8         M1M  Scarborough  Cliffside, Cliffcrest, Scarborough Village West
# 9         M1N  Scarborough                      Birch Cliff, Cliffside West

# %% [markdown]
# Print last 10 rows

# %%
db_f.tail(20)
# Out:
#     Postal_code                                            Borough  \
# 83          M6R                                       West Toronto
# 84          M6S                                       West Toronto
# 85          M7A                                       Queen's Park
# 86          M7R   MississaugaCanada Post Gateway Processing Centre
# 87          M7Y  East TorontoBusiness reply mail Processing Cen...
# 88          M8V                                          Etobicoke
# 89          M8W                                          Etobicoke
# 90          M8X                                          Etobicoke
# 91          M8Y                                          Etobicoke
# 92          M8Z                                          Etobicoke
# 93          M9A                                          Etobicoke
# 94          M9B                                          Etobicoke
# 95          M9C                                          Etobicoke
# ...

# %%
db_f.shape
# Out:
# (103, 3)

# %%
postal_code=db_f['Postal_code']
postal_code
# Out:
# 0      M1B
# 1      M1C
# 2      M1E
# 3      M1G
# 4      M1H
#       ...
# 98     M9N
# 99     M9P
# 100    M9R
# 101    M9V
# 102    M9W
# Name: Postal_code, Length: 103, dtype: object

# %% [markdown]
# Loading cordinates data

# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

if os.environ.get('RUNTIME_ENV_LOCATION_TYPE') == 'external':
    endpoint_d7f61cf5e9114c068bbfb95edc95831e = 'https://s3-api.us-geo.objectstorage.softlayer.net'
else:
    endpoint_d7f61cf5e9114c068bbfb95edc95831e = 'https://s3-api.us-geo.objectstorage.service.networklayer.com'

client_d7f61cf5e9114c068bbfb95edc95831e = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='ijewkXZrOg_q8jzvOUGEBo-gOq0dYKSRna1uXjeOG20X',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url=endpoint_d7f61cf5e9114c068bbfb95edc95831e)

body = client_d7f61cf5e9114c068bbfb95edc95831e.get_object(Bucket='capstoneproject2-donotdelete-pr-lm8wmrn0driu3w',Key='Geospatial_Coordinates.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body)
df_data_1.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
db_f['Latitude'] = '0'
db_f['Longitude'] = '0'


for i in range(len(db_f["Postal_code"])):
        for j in range(len(df_data_1["Postal Code"])):
            if db_f["Postal_code"][i] ==df_data_1["Postal Code"][j]: #if the Postal Code match
                db_f['Latitude'][i] = df_data_1['Latitude'][j] #gets the latitude of the matched  Postal Code
                db_f['Longitude'][i] = df_data_1['Longitude'][j] #gets the longitude

# %%
db_f
# Out:
#     Postal_code             Borough  \
# 0           M1B         Scarborough
# 1           M1C         Scarborough
# 2           M1E         Scarborough
# 3           M1G         Scarborough
# 4           M1H         Scarborough
# ..          ...                 ...
# 98          M9N                York
# 99          M9P           Etobicoke
# 100         M9R           Etobicoke
# 101         M9V           Etobicoke
# 102         M9W  EtobicokeNorthwest
#
#                                           Neighborhood Latitude Longitude
# 0                                       Malvern, Rouge  43.8067  -79.1944
# 1               Rouge Hill, Port Union, Highland Creek  43.7845  -79.1605
# 2                    Guildwood, Morningside, West Hill  43.7636  -79.1887
# 3                                               Woburn   43.771  -79.2169
# 4                                            Cedarbrae  43.7731  -79.2395
# ..                                                 ...      ...       ...
# ...

# %% [markdown]
# Creating map

# %%
address = 'Scarborough'

data1=['0','0']
map_cor=pd.DataFrame(data1).transpose()
map_cor.columns = ['Latitude','Longitude']


map_cor
# Out:
#   Latitude Longitude
# 0        0         0

# %%
len(db_f["Borough"])
# Out:
# 103

# %%
k=0
ii=2
for ii in range(len(db_f['Borough'])):
    if db_f["Borough"][ii] == address:
        #print(ii)
        #a=db_f['Latitude'][ii]
        #print(a)
        map_cor.loc[len(map_cor.index)]= [db_f['Latitude'][ii],db_f['Longitude'][ii]]
#print(k)

# %%
map_cor
# Out:
#    Latitude Longitude
# 0         0         0
# 1   43.8067  -79.1944
# 2   43.7845  -79.1605
# 3   43.7636  -79.1887
# 4    43.771  -79.2169
# 5   43.7731  -79.2395
# 6   43.7447  -79.2395
# 7   43.7279   -79.262
# 8   43.7111  -79.2846
# 9   43.7163  -79.2395
# 10  43.6927  -79.2648
# 11  43.7574  -79.2733
# 12  43.7501  -79.2958
# 13  43.7942   -79.262
# 14  43.7816  -79.3043
# 15  43.8153  -79.2846
# 16  43.7995  -79.3184
# 17  43.8361  -79.2056
# 18  43.8067  -79.1944
# 19  43.7845  -79.1605
# 20  43.7636  -79.1887
# 21   43.771  -79.2169
# 22  43.7731  -79.2395
# 23  43.7447  -79.2395
# 24  43.7279   -79.262
# 25  43.7111  -79.2846
# 26  43.7163  -79.2395
# 27  43.6927  -79.2648
# 28  43.7574  -79.2733
# 29  43.7501  -79.2958
# 30  43.7942   -79.262
# 31  43.7816  -79.3043
# 32  43.8153  -79.2846
# 33  43.7995  -79.3184
# 34  43.8361  -79.2056
# 35  43.8067  -79.1944
# 36  43.7845  -79.1605
# 37  43.7636  -79.1887
# 38   43.771  -79.2169
# 39  43.7731  -79.2395
# ...

# %%
map_cor.reset_index()
map_cor
# Out:
#    Latitude Longitude
# 0         0         0
# 1   43.8067  -79.1944
# 2   43.7845  -79.1605
# 3   43.7636  -79.1887
# 4    43.771  -79.2169
# 5   43.7731  -79.2395
# 6   43.7447  -79.2395
# 7   43.7279   -79.262
# 8   43.7111  -79.2846
# 9   43.7163  -79.2395
# 10  43.6927  -79.2648
# 11  43.7574  -79.2733
# 12  43.7501  -79.2958
# 13  43.7942   -79.262
# 14  43.7816  -79.3043
# 15  43.8153  -79.2846
# 16  43.7995  -79.3184
# 17  43.8361  -79.2056

# %%
map_cor.drop_duplicates()
map_cor
# Out:
#    Latitude Longitude
# 0         0         0
# 1   43.8067  -79.1944
# 2   43.7845  -79.1605
# 3   43.7636  -79.1887
# 4    43.771  -79.2169
# 5   43.7731  -79.2395
# 6   43.7447  -79.2395
# 7   43.7279   -79.262
# 8   43.7111  -79.2846
# 9   43.7163  -79.2395
# 10  43.6927  -79.2648
# 11  43.7574  -79.2733
# 12  43.7501  -79.2958
# 13  43.7942   -79.262
# 14  43.7816  -79.3043
# 15  43.8153  -79.2846
# 16  43.7995  -79.3184
# 17  43.8361  -79.2056

# %% [markdown]
# Dropping row with zeros

# %%
a_series = (map_cor!= '0').any(axis=1)
print(a_series)
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# dtype: bool

# %%
new_map_cor = map_cor.loc[a_series]
new_map_cor
# Out:
#    Latitude Longitude
# 1   43.8067  -79.1944
# 2   43.7845  -79.1605
# 3   43.7636  -79.1887
# 4    43.771  -79.2169
# 5   43.7731  -79.2395
# 6   43.7447  -79.2395
# 7   43.7279   -79.262
# 8   43.7111  -79.2846
# 9   43.7163  -79.2395
# 10  43.6927  -79.2648
# 11  43.7574  -79.2733
# 12  43.7501  -79.2958
# 13  43.7942   -79.262
# 14  43.7816  -79.3043
# 15  43.8153  -79.2846
# 16  43.7995  -79.3184
# 17  43.8361  -79.2056

# %%
new_map_cor.reset_index()
new_map_cor
# Out:
#    Latitude Longitude
# 1   43.8067  -79.1944
# 2   43.7845  -79.1605
# 3   43.7636  -79.1887
# 4    43.771  -79.2169
# 5   43.7731  -79.2395
# 6   43.7447  -79.2395
# 7   43.7279   -79.262
# 8   43.7111  -79.2846
# 9   43.7163  -79.2395
# 10  43.6927  -79.2648
# 11  43.7574  -79.2733
# 12  43.7501  -79.2958
# 13  43.7942   -79.262
# 14  43.7816  -79.3043
# 15  43.8153  -79.2846
# 16  43.7995  -79.3184
# 17  43.8361  -79.2056

# %% [markdown]
# Cluster neighborhoods in 'Scarborough' in map to know the area.

# %%
! pip install folium
import folium
ii=1
LL=new_map_cor['Latitude'][ii]
LG=new_map_cor['Longitude'][ii]
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# ...

# %%
map_newyork = folium.Map(location=[LL,LG], zoom_start=10)

# %%
# add markers to map
for lat, lng, borough, neighborhood in zip(db_f['Latitude'], db_f['Longitude'], db_f['Borough'],db_f['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# From the map, we can see that the area is near the beach, It will be a good tourist spot. So it will be a good area for water entertainment business.
